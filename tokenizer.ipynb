# %%
import os

# %%
def load_training_data():
    possible_paths = [
        '../data/input.txt',
        './data/input.txt',
        'data/input.txt',
        'input.txt'
    ]
    for path in possible_paths:
        if os.path.exists(path):
            print(f"Loading data from: {path}")
            with open(path, 'r', encoding='utf-8') as f:
                return f.read()
    print("No input.txt found, using example text")
    return """
    Hello world! This is a simple example text for training an LSTM model.
    The model will learn to predict the next character in a sequence.
    """

text = load_training_data()
# Out:
# Loading data from: ./data/input.txt

# %%
tokens = text.encode('utf-8')
print(text[:20])

tokens = list(map(int, tokens))
print(tokens[:20])

print("length of text: ", len(text))
print("length of tokens: ", len(tokens))
# Out:
# First Citizen:
# Befor
# [70, 105, 114, 115, 116, 32, 67, 105, 116, 105, 122, 101, 110, 58, 10, 66, 101, 102, 111, 114]
# length of text:  1115394
# length of tokens:  1115394

# %%
def get_stats(tokens):
    counts = {}
    for pair in zip(tokens, tokens[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

counts = get_stats(tokens)
print(sorted(((v, k) for k, v in counts.items()), reverse=True))
# Out:
# [(27643, (101, 32)), (23837, (32, 116)), (22739, (116, 104)), (18203, (104, 101)), (16508, (116, 32)), (15364, (115, 32)), (14165, (100, 32)), (14098, (44, 32)), (13541, (32, 97)), (12730, (111, 117)), (12287, (32, 115)), (11925, (32, 104)), (11771, (101, 114)), (10786, (32, 109)), (10606, (105, 110)), (10546, (32, 119)), (10516, (114, 32)), (10283, (121, 32)), (10197, (97, 110)), (9843, (114, 101)), (9673, (104, 97)), (9306, (110, 100)), (8762, (58, 10)), (8737, (110, 32)), (8463, (32, 98)), (8458, (111, 114)), (8339, (97, 116)), (8134, (111, 32)), (7568, (101, 110)), (7526, (105, 115)), (7410, (32, 111)), (7223, (10, 10)), (7166, (32, 105)), (7081, (97, 114)), (6991, (104, 105)), (6823, (115, 116)), (6676, (46, 10)), (6563, (32, 102)), (6478, (101, 115)), (6435, (111, 110)), (6357, (108, 108)), (6288, (101, 97)), (6135, (109, 101)), (6114, (105, 116)), (5986, (118, 101)), (5860, (116, 111)), (5507, (115, 101)), (5505, (44, 10)), (5478, (32, 100)), (5410, (108, 32)), (5404, (32, 99)), (5313, (117, 114)), (5209, (110, 111)), (5199, (104, 111)), (5176, (32, 110)), (5173, (32, 108)), (5140, (110, 103)), (5140, (32, 121)), (5117, (104, 32)), (4728, (121, 111)), (4682, (102, 32)), (4490, (32, 112)), (4433, (116, 101)), (4423, (108, 101)), (4342, (73, 32)), (4149, (97, 108)), (4142, (10, 84)), (4079, (32, 73)), (4060, (111, 116)), (3964, (111, 119)), (3959, (98, 101)), (3920, (110, 101)), (3893, (97, 115)), (3865, (119, 105)), (3839, (101, 44)), (3836, (111, 102)), (3832, (10, 65)), (3807, (101, 101)), (3700, (110, 116)), (3676, (101, 100)), (3653, (117, 32)), (3614, (111, 109)), (3613, (114, 111)), (3556, (101, 108)), (3512, (32, 103)), (3480, (100, 101)), (3375, (108, 111)), (3354, (99, 101)), (3339, (109, 97)), (3325, (102, 111)), (3274, (117, 115)), (3159, (115, 104)), (3118, (99, 111)), (3106, (99, 104)), (3082, (105, 108)), (3060, (101, 116)), (3028, (84, 104)), (3016, (114, 105)), (2982, (119, 101)), (2977, (116, 105)), (2919, (109, 121)), (2902, (117, 116)), (2831, (115, 111)), (2811, (108, 105)), (2729, (10, 87)), (2700, (105, 114)), (2685, (97, 32)), (2651, (114, 100)), (2649, (114, 115)), (2634, (111, 111)), (2627, (114, 97)), (2594, (97, 121)), (2561, (103, 32)), (2535, (109, 32)), (2496, (10, 73)), (2471, (97, 118)), (2412, (115, 44)), (2392, (108, 100)), (2369, (32, 114)), (2333, (107, 101)), (2323, (97, 105)), (2306, (108, 97)), (2278, (114, 116)), (2259, (105, 101)), (2242, (32, 101)), (2230, (119, 104)), (2226, (117, 108)), (2168, (117, 110)), (2144, (97, 100)), (2125, (105, 109)), (2114, (65, 110)), (2099, (39, 115)), (2094, (115, 105)), (2040, (119, 97)), (2024, (103, 104)), (2024, (100, 111)), (2012, (110, 99)), (2006, (100, 44)), (1997, (105, 99)), (1989, (112, 101)), (1957, (116, 97)), (1941, (116, 44)), (1937, (103, 101)), (1919, (119, 111)), (1910, (59, 32)), (1874, (32, 117)), (1865, (116, 114)), (1849, (119, 32)), (1846, (115, 115)), (1836, (109, 111)), (1833, (63, 10)), (1793, (87, 104)), (1753, (97, 109)), (1748, (100, 105)), (1720, (112, 114)), (1700, (101, 109)), (1689, (59, 10)), (1684, (111, 100)), (1671, (10, 83)), (1669, (10, 66)), (1668, (110, 115)), (1666, (121, 44)), (1644, (111, 108)), (1636, (101, 46)), (1615, (99, 97)), (1607, (97, 99)), (1603, (104, 121)), (1592, (32, 107)), (1572, (105, 111)), (1569, (111, 115)), (1561, (97, 107)), (1554, (10, 72)), (1540, (114, 44)), (1527, (102, 97)), (1513, (58, 32)), (1508, (105, 103)), (1494, (79, 58)), (1493, (102, 101)), (1473, (109, 105)), (1463, (105, 100)), (1454, (39, 100)), (1443, (112, 111)), (1437, (103, 111)), (1434, (101, 10)), (1426, (108, 121)), (1403, (107, 32)), (1399, (10, 77)), (1380, (104, 116)), (1376, (100, 115)), (1373, (69, 78)), (1365, (115, 97)), (1356, (110, 44)), (1329, (98, 117)), (1314, (101, 105)), (1313, (73, 78)), (1289, (115, 117)), (1277, (98, 108)), (1254, (73, 79)), (1240, (112, 97)), (1238, (111, 118)), (1237, (101, 99)), (1230, (83, 58)), (1229, (33, 10)), (1206, (10, 70)), (1188, (114, 121)), (1184, (105, 102)), (1 ...

# %%
top_pair = max(counts, key=counts.get)
print(top_pair)
# Out:
# (101, 32)

# %%
def merge(ids, pair, idx):
    newid = []
    i = 0
    while i < len(ids):
        if i < len(ids) - 1:
            get_pair = (ids[i], ids[i+1])
            if get_pair == pair:
                newid.append(idx)
                i += 2
            else:
                newid.append(ids[i])
                i += 1
        else:
            newid.append(ids[i])
            i += 1
    return newid

print(merge([1, 2, 3, 4, 3, 4], (4, 3), 99))
# Out:
# [1, 2, 3, 99, 4]

# %%
vocab_size = 1000
num_merges = vocab_size - 256
ids = list(tokens)

merges = {} # (int, int) -> int
for i in range(num_merges):
    stats = get_stats(ids)
    pair = max(stats, key=stats.get)
    idx = 256 + i
    merges[pair] = idx
    print(f"Merging {pair} into {idx}")
    ids = merge(ids, pair, idx)
# Out:
# Merging (101, 32) into 256
# Merging (116, 104) into 257
# Merging (116, 32) into 258
# Merging (115, 32) into 259
# Merging (100, 32) into 260
# Merging (44, 32) into 261
# Merging (111, 117) into 262
# Merging (101, 114) into 263
# Merging (105, 110) into 264
# Merging (121, 32) into 265
# Merging (97, 110) into 266
# Merging (58, 10) into 267
# Merging (111, 114) into 268
# Merging (111, 32) into 269
# Merging (101, 110) into 270
# Merging (10, 10) into 271
# Merging (97, 114) into 272
# Merging (32, 257) into 273
# Merging (111, 110) into 274
# Merging (108, 108) into 275
# Merging (104, 97) into 276
# Merging (44, 10) into 277
# Merging (46, 271) into 278
# Merging (105, 259) into 279
# Merging (101, 115) into 280
# Merging (121, 262) into 281
# Merging (32, 115) into 282
# Merging (116, 269) into 283
# Merging (266, 260) into 284
# Merging (111, 119) into 285
# Merging (101, 97) into 286
# Merging (32, 109) into 287
# Merging (32, 119) into 288
# Merging (111, 102) into 289
# Merging (32, 104) into 290
# Merging (264, 103) into 291
# Merging (111, 109) into 292
# Merging (32, 97) into 293
# Merging (99, 104) into 294
# Merging (257, 256) into 295
# Merging (115, 116) into 296
# Merging (32, 98) into 297
# Merging (110, 111) into 298
# Merging (105, 114) into 299
# Merging (102, 268) into 300
# Merging (118, 256) into 301
# Merging (101, 261) into 302
# Merging (105, 257) into 303
# Merging (273, 256) into 304
# Merging (115, 101) into 305
# Merging (108, 105) into 306
# Merging (84, 104) into 307
# Merging (275, 32) into 308
# Merging (114, 101) into 309
# Merging (115, 258) into 310
# Merging (97, 258) into 311
# Merging (65, 110) into 312
# Merging (73, 32) into 313
# Merging (101, 272) into 314
# Merging (105, 109) into 315
# Merging (105, 116) into 316
# Merging (111, 111) into 317
# Merging (103, 104) into 318
# Merging (97, 116) into 319
# Merging (105, 115) into 320
# Merging (108, 101) into 321
# Merging (263, 32) into 322
# Merging (262, 114) into 323
# Merging (312, 260) into 324
# Merging (39, 259) into 325
# Merging (101, 101) into 326
# Merging (298, 258) into 327
# Merging (109, 265) into 328
# Merging (59, 10) into 329
# Merging (114, 97) into 330
# Merging (46, 10) into 331
# Merging (281, 114) into 332
# Merging (117, 114) into 333
# Merging (276, 258) into 334
# Merging (114, 105) into 335
# Merging (117, 258) into 336
# Merging (108, 260) into 337
# Merging (289, 32) into 338
# Merging (79, 267) into 339
# Merging (101, 260) into 340
# Merging (108, 97) into 341
# Merging (105, 258) into 342
# Merging (114, 111) into 343
# Merging (263, 256) into 344
# Merging (101, 259) into 345
# Merging (100, 261) into 346
# Merging (117, 110) into 347
# Merging (69, 78) into 348
# Merging (107, 256) into 349
# Merging (121, 261) into 350
# Merging (73, 78) into 351
# Merging (32, 100) into 352
# Merging (63, 271) into 353
# Merging (97, 259) into 354
# Merging (102, 97) into 355
# Merging (119, 303) into 356
# Merging (276, 301) into 357
# Merging (83, 267) into 358
# Merging (32, 99) into 359
# Merging (87, 104) into 360
# Merging (257, 311) into 361
# Merging (270, 116) into 362
# Merging (257, 101) into 363
# Merging (99, 101) into 364
# Merging (115, 104) into 365
# Merging (109, 97) into 366
# Merging (32, 112) into 367
# Merging (257, 263) into 368
# Merging (98, 101) into 369
# Merging (46, 32) into 370
# Merging (65, 82) into 371
# Merging (99, 256) into 372
# Merging (291, 32) into 373
# Merging (97, 108) into 374
# Merging (59, 32) into 375
# Merging (257, 262) into 376
# Merging (115, 261) into 377
# Merging (109, 256) into 378
# Merging (115, 256) into 379
# Merging (108, 111) into 380
# Merging (99, 107) into 381
# Merging (119, 104) into 382
# Merging (105, 108) into 383
# Merging (39, 260) into 384
# Merging (73, 339) into 385
# Merging (110, 285) into 386
# Merging (105, 275) into 387
# Merging (98, 256) into 388
# Merging (101, 275) into 389
# Merging (114, 286) into 390
# Merging (32, 116) into 391
# Merging (116, 261) into 392
# Merging (262, 337) into 393
# Merging (101, 10) into 394
# Merging (287, 265) into 395
# Merging (118, 263) into 396
# Merging (99, 292) into 397
# Merging (104, 256) into 398
# Merging (32, 283) into 399
# Merging (32, 73) into 400
# Merging (101, 108) into 401
# Merging (85, 358) into 402
# Merging (111, 108) into 403
# Merging (100, 105) into 404
# Merging (32, 103) into 405
# Merging (97, 265) into 406
# Merging (116, 263) into 407
# Merging (97, 264) into 408
# Merging (32, 281) into 409
# Merging (307, 256) into 410
# Merging (108, 256) into 411
# Merging (105, 274) into 412
# Merging (32, 102) into 413
# Merging (114, 117) into 414
# Merging (105, 102) into 415
# Merging (101, 109) into 416
# Merging (266, 100) into 417
# Merging (84, 269) into 418
# Merging (105, 318) into 419
# Merging (272, 256) into 420
# Merging (117, 112) into 421
# Merging (277, 324) into 422
# Merging (104, 315) into 423
# Merging (101, 100) into 424
# Merging (105, 308) into 425
# Merging (268, 100) into 426
# Merging (105, 294) into 427
# Merging (108, 265) into 428
# Merging (317, 260) into 429
# Merging (85, 67) into 430
# Merging (285, 110) into 431
# Merging (104, 279) into 432
# Merging (351, 71) into 433
# Merging (32, 284) into 434
# Merging (99, 274) into 435
# Merging (110, 101) into 436
# Merging (97, 121) into 437
# Merging (101, 278) into 438
# Merging (114, 292) into 439
# Merging (105, 100) into 440
# Merging (117, 115) into 441
# Merging (262, 110) into 442
# Merging (65, 78) into 443
# Merging (109, 266) into 444
# Merging (97, 103) into 445
# Merging (69, 82) into 446
# Merging (79, 82) into 447
# Merging (101, 258) into 448
# Merging (114, 280) into 449
# Merging (305, 108) into 450
# Merging (290, 279) into 451
# Merging (101, 277) into 452
# Merging (101, 116) into 453
# Merging (99, 97) into 454
# Merging (32, 264) into 455
# Merging (115, 276) into 456
# Merging (33, 10) into 457
# Merging (69, 84) into 458
# Merging (84, 334) into 459
# Merging (112, 111) into 460
# Merging (113, 117) into 461
# Merging (257, 265) into 462
# Merging (33, 271) into 463
# Merging (109, 268) into 464
# Merging (117, 108) into 465
# Merging (110, 269) into 466
# Merging (97, 109) into 467
# Merging (273, 101) into 468
# Merging (65, 267) into 469
# Merging (118, 270) into 470
# Merging (98, 265) into 471
# Merging (115, 10) into 472
# Merging (115, 112) into 473
# Merging (75, 433) into 474
# Merging (290, 315) into 475
# Merging (257, 279) into 476
# Merging (273, 279) into 477
# Merging (104, 263) into 478
# Merging (273, 311) into 479
# Merging (111, 257) into 480
# Merging (63, 10) into 481
# Merging (274, 103) into 482
# Merging (66, 336) into 483
# Merging (280, 258) into 484
# Merging (111, 261) into 485
# Merging (98, 336) into 486
# Merging (32, 289) into 487
# Merging (70, 268) into 488
# Merging (115, 117) into 489
# Merging (288, 303) into 490
# Merging (117, 116) into 491
# Merging (274, 256) into 492
# Merging (97, 275) into 493
# Merging (73, 67) into 494
# Merging (270, 100) into 495
# Merging (79, 76) into 496
# Merging (100, 269) into 497
# Merging (73, 288) into 498
# Merging (292, 256) into 499
# Merging (107, 386) into 500
# Merging (115, 277) into 501
# Merging (115, 299) into 502
# Merging (261, 284) into 503
# Merging (99, 116) into 504
# Merging (117, 259) into 505
# Merging (280, 259) into 506
# Merging (450, 102) into 507
# Merging (282, 116) into 508
# Merging (97, 349) into 509
# Merging (69, 76) into 510
# Merging (107, 291) into 511
# Merging (108, 286) into 512
# Merging (288, 104) into 513
# Merging (272, 100) into 514
# Merging (111, 112) into 515
# Merging (119, 268) into 516
# Merging (297, 256) into 517
# Merging (97, 100) into 518
# Merging (73, 402) into 519
# Merging (474, 32) into 520
# Merging (371, 68) into 521
# Merging (273, 262) into 522
# Merging (115, 269) into 523
# Merging (32, 332) into 524
# Merging (104, 314) into 525
# Merging (270, 258) into 526
# Merging (109, 111) into 527
# Merging (280, 116) into 528
# Merging (116, 111) into 529
# Merging (45, 45) into 530
# Merging (99, 105) into 531
# Merging (83, 84) into 532
# Merging (77, 265) into 533
# Merging (281, 32) into 534
# Merging (270, 32) into 535
# Merging (39, 116) into 536
# Merging (262, 259) into 537
# Merging (119, 256) into 538
# Merging (100, 10) into 539
# Merging (108, 317) into 540
# Merging (58, 32) into 541
# Merging (69, 267) into 542
# Merging (100, 101) into 543
# Merging (33, 32) into 544
# Merging (73, 39) into 545
# Merging (293, 109) into 546
# Merging (273, 265) into 547
# Merging (79, 78) into 548
# Merging (290, 256) into 549
# Merging (264, 32) into 550
# Merging (114, 266) into 551
# Merging (264, 107) into 552
# Merging (115, 97) into 553
# Merging (100, 286) into 554
# Merging (266, 32) into 555
# Merging (263, 101) into 556
# Merging (117, 294) into 557
# Merging (282, 276) into 558
# Merging (320, 104) into 559
# Merging (115, 274) into 560
# Merging (105, 301) into 561
# Merging (102, 439) into 562
# Merging (103, 429) into 563
# Merging (117, 310) into 564
# Merging (115, 119) into 565
# Merging (278, 67) into 566
# Merging (97, 98) into 567
# Merging (108, 426) into 568
# Merging (65, 259) into 569
# Merging (276, 257) into 570
# Merging (87, 334) into 571
# Merging (278, 80) into 572
# Merging (97, 32) into 573
# Merging (286, 107) into 574
# Merging (114, 285) into 575
# Merging (116, 10) into 576
# Merging (264, 256) into 577
# Merging (262, 108) into 578
# Merging (105, 103) into 579
# Merging (100, 263) into 580
# Merging (89, 262) into 581
# Merging (112, 263) into 582
# Merging (380, 118) into 583
# Merging (278, 76) into 584
# Merging (112, 114) into 585
# Merging (306, 349) into 586
# Merging (521, 400) into 587
# Merging (72, 97) into 588
# Merging (329, 324) into 589
# Merging (82, 79) into 590
# Merging (256, 283) into 591
# Merging (280, 115) into 592
# Merging (84, 385) into 593
# Merging (109, 101) into 594
# Merging (105, 99) into 595
# Merging (262, 318) into 596
# Merging (282, 104) into 597
# Merging (421, 274) into 598
# Merging (73, 267) into 599
# Merging (262, 258) into 600
# Merging (268, 32) into 601
# Merging (121, 10) into 602
# Merging (458, 267) into 603
# Merging (119, 354) into 604
# Merging (65, 85) into 605
# Merging (112, 343) into 606
# Merging (99, 266) into 607
# Merging (119, 334) into 608
# Merging (263, 118) into 609
# Merging (321, 258) into 610
# Merging (97, 350) into 611
# Merging (89, 32) into 612
# Merging (266, 116) into 613
# Merging (105, 260) into 614
# Merging (313, 357) into 615
# Merging (69, 32) into 616
# Merging (323, 32) into 617
# Merging (297, 336) into 618
# Merging (300, 32) into 619
# Merging (297, 101) into 620
# Merging (104, 286) into 621
# Merging (306, 102) into 622
# Merging (97, 115) into 623
# Merging (119, 389) into 624
# Merging (101, 121) into 625
# Merging (111, 337) into 626
# Merging (277, 360) into 627
# Merging (73, 110) into 628
# Merging (299, 310) into 629
# Merging (117, 109) into 630
# Merging (63, 32) into 631
# Merging (266, 103) into 632
# Merging (73, 546) into 633
# Merging (32, 338) into 634
# Merging (105, 296) into 635
# Merging (363, 109) into 636
# Merging (270, 260) into 637
# Merging (75, 267) into 638
# Merging (276, 116) into 639
# Merging (73, 102) into 640
# Merging (332, 32) into 641
# Merging (494, 72) into 642
# Merging (119, 272) into 643
# Merging (82, 642) into 644
# Merging (326, 112) into 645
# Merging (376, 32) into 646
# Merging (68, 85) into 647
# Merging (647, 75) into 648
# Merging (102, 465) into 649
# Merging (648, 616) into 650
# Merging (115, 111) into 651
# Merging (111, 100) into 652
# Merging (293, 259) into 653
# Merging (116, 116) into 654
# Merging (300, 256) into 655
# Merging (116, 414) into 656
# Merging (105, 381) into 657
# Merging (276, 260) into 658
# Merging (87, 303) into 659
# Merging (98, 411) into 660
# Merging (419, 116) into 661
# Merging (112, 112) into 662
# Merging (348, 593) into 663
# Merging (116, 315) into 664
# Merging (446, 267) into 665
# Merging (264, 100) into 666
# Merging (464, 256) into 667
# Merging (73, 282) into 668
# Merging (363, 265) into 669
# Merging (280, 261) into 670
# Merging (278, 66) into 671
# Merging (456, 275) into 672
# Merging (280, 256) into 673
# Merging (278, 520) into 674
# Merging (278, 83) into 675
# Merging (119, 425) into 676
# Merging (355, 368) into 677
# Merging (101, 120) into 678
# Merging (278, 71) into 679
# Merging (100, 111) into 680
# Merging (375, 284) into 681
# Merging (89, 267) into 682
# Merging (257, 270) into 683
# Merging (290, 263) into 684
# Merging (119, 344) into 685
# Merging (293, 275) into 686
# Merging (79, 261) into 687
# Merging (351, 67) into 688
# Merging (285, 32) into 689
# Merging (287, 256) into 690
# Merging (101, 325) into 691
# Merging (98, 108) into 692
# Merging (72, 256) into 693
# Merging (108, 268) into 694
# Merging (278, 77) into 695
# Merging (111, 379) into 696
# Merging (579, 110) into 697
# Merging (98, 343) into 698
# Merging (283, 295) into 699
# Merging (114, 265) into 700
# Merging (117, 318) into 701
# Merging (79, 102) into 702
# Merging (287, 101) into 703
# Merging (101, 112) into 704
# Merging (396, 265) into 705
# Merging (292, 101) into 706
# Merging (264, 304) into 707
# Merging (270, 364) into 708
# Merging (10, 418) into 709
# Merging (65, 66) into 710
# Merging (119, 387) into 711
# Merging (102, 335) into 712
# Merging (554, 257) into 713
# Merging (270, 372) into 714
# Merging (100, 277) into 715
# Merging (293, 32) into 716
# Merging (419, 258) into 717
# Merging (112, 272) into 718
# Merging (266, 265) into 719
# Merging (540, 107) into 720
# Merging (97, 119) into 721
# Merging (366, 349) into 722
# Merging (545, 308) into 723
# Merging (76, 79) into 724
# Merging (644, 587) into 725
# Merging (70, 629) into 726
# Merging (69, 532) into 727
# Merging (257, 322) into 728
# Merging (436, 119) into 729
# Merging (363, 299) into 730
# Merging (288, 334) into 731
# Merging (430, 72) into 732
# Merging (105, 118) into 733
# Merging (119, 393) into 734
# Merging (99, 302) into 735
# Merging (259, 284) into 736
# Merging (103, 330) into 737
# Merging (103, 101) into 738
# Merging (272, 109) into 739
# Merging (724, 430) into 740
# Merging (740, 727) into 741
# Merging (741, 665) into 742
# Merging (121, 448) into 743
# Merging (355, 299) into 744
# Merging (118, 111) into 745
# Merging (114, 431) into 746
# Merging (69, 348) into 747
# Merging (363, 256) into 748
# Merging (468, 299) into 749
# Merging (307, 279) into 750
# Merging (382, 427) into 751
# Merging (282, 269) into 752
# Merging (307, 262) into 753
# Merging (76, 73) into 754
# Merging (333, 256) into 755
# Merging (288, 256) into 756
# Merging (366, 100) into 757
# Merging (121, 507) into 758
# Merging (365, 256) into 759
# Merging (101, 102) into 760
# Merging (296, 263) into 761
# Merging (274, 323) into 762
# Merging (101, 118) into 763
# Merging (261, 328) into 764
# Merging (306, 118) into 765
# Merging (101, 308) into 766
# Merging (380, 301) into 767
# Merging (326, 258) into 768
# Merging (101, 504) into 769
# Merging (264, 260) into 770
# Merging (273, 416) into 771
# Merging (289, 304) into 772
# Merging (257, 266) into 773
# Merging (404, 260) into 774
# Merging (81, 85) into 775
# Merging (775, 747) into 776
# Merging (86, 688) into 777
# Merging (777, 663) into 778
# Merging (456, 308) into 779
# Merging (67, 292) into 780
# Merging (79, 70) into 781
# Merging (781, 32) into 782
# Merging (289, 102) into 783
# Merging (298, 116) into 784
# Merging (333, 110) into 785
# Merging (77, 272) into 786
# Merging (282, 112) into 787
# Merging (326, 100) into 788
# Merging (257, 291) into 789
# Merging (356, 32) into 790
# Merging (32, 300) into 791
# Merging (65, 77) into 792
# Merging (118, 105) into 793
# Merging (101, 270) into 794
# Merging (72, 348) into 795
# Merging (112, 341) into 796
# Merging (111, 39) into 797
# Merging (97, 107) into 798
# Merging (445, 408) into 799
# Merging (502, 261) into 800
# Merging (117, 379) into 801
# Merging (318, 116) into 802
# Merging (103, 561) into 803
# Merging (10, 324) into 804
# Merging (121, 277) into 805
# Merging (103, 111) into 806
# Merging (71, 111) into 807
# Merging (97, 308) into 808
# Merging (397, 256) into 809
# Merging (83, 269) into 810
# Merging (795, 82) into 811
# Merging (811, 612) into 812
# Merging (101, 99) into 813
# Merging (109, 272) into 814
# Merging (536, 279) into 815
# Merging (69, 83) into 816
# Merging (305, 260) into 817
# Merging (318, 258) into 818
# Merging (103, 256) into 819
# Merging (267, 65) into 820
# Merging (268, 256) into 821
# Merging (290, 314) into 822
# Merging (116, 509) into 823
# Merging (362, 321) into 824
# Merging (100, 320) into 825
# Merging (447, 73) into 826
# Merging (110, 103) into 827
# Merging (262, 115) into 828
# Merging (111, 368) into 829
# Merging (98, 263) into 830
# Merging (104, 322) into 831
# Merging (100, 117) into 832
# Merging (650, 778) into 833
# Merging (32, 279) into 834
# Merging (776, 32) into 835
# Merging (106, 111) into 836
# Merging (69, 358) into 837
# Merging (73, 259) into 838
# Merging (285, 263) into 839
# Merging (101, 39) into 840
# Merging (274, 101) into 841
# Merging (109, 270) into 842
# Merging (89, 447) into 843
# Merging (843, 638) into 844
# Merging (99, 442) into 845
# Merging (97, 112) into 846
# Merging (272, 258) into 847
# Merging (117, 296) into 848
# Merging (319, 256) into 849
# Merging (100, 280) into 850
# Merging (87, 256) into 851
# Merging (319, 412) into 852
# Merging (79, 114) into 853
# Merging (473, 574) into 854
# Merging (32, 342) into 855
# Merging (102, 105) into 856
# Merging (351, 519) into 857
# Merging (32, 327) into 858
# Merging (112, 330) into 859
# Merging (39, 100) into 860
# Merging (116, 119) into 861
# Merging (267, 78) into 862
# Merging (359, 292) into 863
# Merging (105, 122) into 864
# Merging (273, 266) into 865
# Merging (366, 265) into 866
# Merging (268, 110) into 867
# Merging (281, 261) into 868
# Merging (280, 10) into 869
# Merging (97, 99) into 870
# Merging (39, 84) into 871
# Merging (73, 258) into 872
# Merging (109, 557) into 873
# Merging (69, 68) into 874
# Merging (874, 87) into 875
# Merging (108, 417) into 876
# Merging (97, 701) into 877
# Merging (44, 530) into 878
# Merging (111, 310) into 879
# Merging (390, 258) into 880
# Merging (365, 393) into 881
# Merging (360, 427) into 882
# Merging (84, 72) into 883
# Merging (317, 107) into 884
# Merging (103, 408) into 885
# Merging (382, 270) into 886
# Merging (85, 77) into 887
# Merging (360, 350) into 888
# Merging (98, 111) into 889
# Merging (65, 76) into 890
# Merging (116, 322) into 891
# Merging (73, 287) into 892
# Merging (527, 310) into 893
# Merging (108, 482) into 894
# Merging (102, 314) into 895
# Merging (290, 286) into 896
# Merging (442, 100) into 897
# Merging (32, 313) into 898
# Merging (73, 83) into 899
# Merging (116, 259) into 900
# Merging (115, 499) into 901
# Merging (510, 76) into 902
# Merging (329, 488) into 903
# Merging (435, 260) into 904
# Merging (116, 340) into 905
# Merging (266, 258) into 906
# Merging (69, 100) into 907
# Merging (257, 552) into 908
# Merging (298, 660) into 909
# Merging (268, 260) into 910
# Merging (97, 381) into 911
# Merging (39, 310) into 912
# Merging (79, 77) into 913
# Merging (108, 506) into 914
# Merging (277, 418) into 915
# Merging (77, 69) into 916
# Merging (276, 392) into 917
# Merging (103, 269) into 918
# Merging (277, 459) into 919
# Merging (272, 101) into 920
# Merging (104, 285) into 921
# Merging (65, 80) into 922
# Merging (590, 916) into 923
# Merging (923, 339) into 924
# Merging (348, 348) into 925
# Merging (925, 519) into 926
# Merging (303, 263) into 927
# Merging (287, 266) into 928
# Merging (302, 284) into 929
# Merging (104, 344) into 930
# Merging (66, 265) into 931
# Merging (109, 564) into 932
# Merging (112, 449) into 933
# Merging (97, 102) into 934
# Merging (309, 109) into 935
# Merging (458, 82) into 936
# Merging (936, 732) into 937
# Merging (937, 385) into 938
# Merging (309, 112) into 939
# Merging (259, 283) into 940
# Merging (297, 265) into 941
# Merging (116, 389) into 942
# Merging (105, 112) into 943
# Merging (111, 258) into 944
# Merging (72, 285) into 945
# Merging (108, 121) into 946
# Merging (109, 362) into 947
# Merging (259, 289) into 948
# Merging (272, 260) into 949
# Merging (807, 260) into 950
# Merging (101, 904) into 951
# Merging (103, 117) into 952
# Merging (10, 65) into 953
# Merging (100, 265) into 954
# Merging (694, 346) into 955
# Merging (309, 116) into 956
# Merging (780, 302) into 957
# Merging (10, 410) into 958
# Merging (264, 372) into 959
# Merging (274, 32) into 960
# Merging (82, 706) into 961
# Merging (268, 116) into 962
# Merging (548, 84) into 963
# Merging (111, 275) into 964
# Merging (266, 346) into 965
# Merging (101, 331) into 966
# Merging (267, 307) into 967
# Merging (413, 439) into 968
# Merging (267, 83) into 969
# Merging (712, 495) into 970
# Merging (826, 496) into 971
# Merging (971, 443) into 972
# Merging (293, 258) into 973
# Merging (607, 327) into 974
# Merging (558, 308) into 975
# Merging (403, 100) into 976
# Merging (972, 402) into 977
# Merging (101, 353) into 978
# Merging (114, 482) into 979
# Merging (115, 99) into 980
# Merging (344, 279) into 981
# Merging (100, 437) into 982
# Merging (674, 725) into 983
# Merging (66, 101) into 984
# Merging (257, 319) into 985
# Merging (114, 121) into 986
# Merging (112, 101) into 987
# Merging (286, 108) into 988
# Merging (115, 115) into 989
# Merging (110, 97) into 990
# Merging (461, 794) into 991
# Merging (82, 427) into 992
# Merging (119, 657) into 993
# Merging (278, 726) into 994
# Merging (110, 506) into 995
# Merging (114, 270) into 996
# Merging (319, 294) into 997
# Merging (333, 305) into 998
# Merging (316, 864) into 999

# %%
print("token length: ", len(tokens))
print("ids length: ", len(ids))
print("compression ratio: ", len(tokens) / len(ids))
# Out:
# token length:  1115394
# ids length:  447069
# compression ratio:  2.494903471276246

# %%
vocab = {idx: bytes([idx]) for idx in range(256)}

for (p0, p1), idx in merges.items():
    pair = vocab[p0] + vocab[p1]
    vocab[idx] = pair

print(vocab)

def decode(ids):
    tokens = b"".join(vocab[idx] for idx in ids)
    text = tokens.decode('utf-8', errors = 'replace')
    return text

print(decode([260]))
# Out:
# {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27: b'\x1b', 28: b'\x1c', 29: b'\x1d', 30: b'\x1e', 31: b'\x1f', 32: b' ', 33: b'!', 34: b'"', 35: b'#', 36: b'$', 37: b'%', 38: b'&', 39: b"'", 40: b'(', 41: b')', 42: b'*', 43: b'+', 44: b',', 45: b'-', 46: b'.', 47: b'/', 48: b'0', 49: b'1', 50: b'2', 51: b'3', 52: b'4', 53: b'5', 54: b'6', 55: b'7', 56: b'8', 57: b'9', 58: b':', 59: b';', 60: b'<', 61: b'=', 62: b'>', 63: b'?', 64: b'@', 65: b'A', 66: b'B', 67: b'C', 68: b'D', 69: b'E', 70: b'F', 71: b'G', 72: b'H', 73: b'I', 74: b'J', 75: b'K', 76: b'L', 77: b'M', 78: b'N', 79: b'O', 80: b'P', 81: b'Q', 82: b'R', 83: b'S', 84: b'T', 85: b'U', 86: b'V', 87: b'W', 88: b'X', 89: b'Y', 90: b'Z', 91: b'[', 92: b'\\', 93: b']', 94: b'^', 95: b'_', 96: b'`', 97: b'a', 98: b'b', 99: b'c', 100: b'd', 101: b'e', 102: b'f', 103: b'g', 104: b'h', 105: b'i', 106: b'j', 107: b'k', 108: b'l', 109: b'm', 110: b'n', 111: b'o', 112: b'p', 113: b'q', 114: b'r', 115: b's', 116: b't', 117: b'u', 118: b'v', 119: b'w', 120: b'x', 121: b'y', 122: b'z', 123: b'{', 124: b'|', 125: b'}', 126: b'~', 127: b'\x7f', 128: b'\x80', 129: b'\x81', 130: b'\x82', 131: b'\x83', 132: b'\x84', 133: b'\x85', 134: b'\x86', 135: b'\x87', 136: b'\x88', 137: b'\x89', 138: b'\x8a', 139: b'\x8b', 140: b'\x8c', 141: b'\x8d', 142: b'\x8e', 143: b'\x8f', 144: b'\x90', 145: b'\x91', 146: b'\x92', 147: b'\x93', 148: b'\x94', 149: b'\x95', 150: b'\x96', 151: b'\x97', 152: b'\x98', 153: b'\x99', 154: b'\x9a', 155: b'\x9b', 156: b'\x9c', 157: b'\x9d', 158: b'\x9e', 159: b'\x9f', 160: b'\xa0', 161: b'\xa1', 162: b'\xa2', 163: b'\xa3', 164: b'\xa4', 165: b'\xa5', 166: b'\xa6', 167: b'\xa7', 168: b'\xa8', 169: b'\xa9', 170: b'\xaa', 171: b'\xab', 172: b'\xac', 173: b'\xad', 174: b'\xae', 175: b'\xaf', 176: b'\xb0', 177: b'\xb1', 178: b'\xb2', 179: b'\xb3', 180: b'\xb4', 181: b'\xb5', 182: b'\xb6', 183: b'\xb7', 184: b'\xb8', 185: b'\xb9', 186: b'\xba', 187: b'\xbb', 188: b'\xbc', 189: b'\xbd', 190: b'\xbe', 191: b'\xbf', 192: b'\xc0', 193: b'\xc1', 194: b'\xc2', 195: b'\xc3', 196: b'\xc4', 197: b'\xc5', 198: b'\xc6', 199: b'\xc7', 200: b'\xc8', 201: b'\xc9', 202: b'\xca', 203: b'\xcb', 204: b'\xcc', 205: b'\xcd', 206: b'\xce', 207: b'\xcf', 208: b'\xd0', 209: b'\xd1', 210: b'\xd2', 211: b'\xd3', 212: b'\xd4', 213: b'\xd5', 214: b'\xd6', 215: b'\xd7', 216: b'\xd8', 217: b'\xd9', 218: b'\xda', 219: b'\xdb', 220: b'\xdc', 221: b'\xdd', 222: b'\xde', 223: b'\xdf', 224: b'\xe0', 225: b'\xe1', 226: b'\xe2', 227: b'\xe3', 228: b'\xe4', 229: b'\xe5', 230: b'\xe6', 231: b'\xe7', 232: b'\xe8', 233: b'\xe9', 234: b'\xea', 235: b'\xeb', 236: b'\xec', 237: b'\xed', 238: b'\xee', 239: b'\xef', 240: b'\xf0', 241: b'\xf1', 242: b'\xf2', 243: b'\xf3', 244: b'\xf4', 245: b'\xf5', 246: b'\xf6', 247: b'\xf7', 248: b'\xf8', 249: b'\xf9', 250: b'\xfa', 251: b'\xfb', 252: b'\xfc', 253: b'\xfd', 254: b'\xfe', 255: b'\xff', 256: b'e ', 257: b'th', 258: b't ', 259: b's ', 260: b'd ', 261: b', ', 262: b'ou', 263: b'er', 264: b'in', 265: b'y ', 266: b'an', 267: b':\n', 268: b'or', 269: b'o ', 270: b'en', 271: b'\n\n', 272: b'ar', 273: b' th', 274: b'on', 275: b'll', 276: b'ha', 277: b',\n', 278: b'.\n\n', 279: b'is ', 280: b'es', 281: b'you', 282: b' s', 283: b'to ', 284: b'and ', 285: b'ow', 286: b'ea', 287: b' m', 288: b' w', 289: b'of', 290: b' h', 291: b'ing', 292: b'om', 293: b' a', 294: b'ch', 295: b'the ', 296: b'st', 297: b' b', 298: b'no', 299: b'ir', 300: b'for', 301: b've ', 302: b'e, ', 303: b'ith', 304: b' the ', 305: b'se', 306: b'li', 307: b'Th', 308: b'll ', 309: b're', 310: b'st ', 311: b'at ', 312: b'An', 313: b'I ', 314: b'ear', 315: b'im', 316: b'it', 317: b'oo', 318: b'gh', 319: b'at', 320: b'is', 321: b'l ...
# d

# %%
def encode(text):
    tokens = list(text.encode("utf-8"))
    while True:
        stats = get_stats(tokens)
        best = min(stats, key = lambda p: stats.get(p, float('-inf')))
        if best not in merges:
            break
        idx = merges[best]
        tokens = merge(tokens, best, idx)
    return tokens

print(encode("Hello"))
# Out:
# [72, 101, 108, 108, 111]
